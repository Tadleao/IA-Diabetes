# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

# %%
# Assuming 'data' is your n-dimensional dataset
# data.shape should be (n_samples, n_features)

# Reduce the dimensionality to 2 using PCA
df = pd.read_csv('balanced_under.csv')
df_std = (df - df.mean()) / df.std()
df_std
# Out:
#            C006      C008    I00102   Q046017   Q046015   Q046018    Q03802  \
# 0     -1.413295  1.536507  0.602531 -0.255562  2.107125 -0.781794  0.665224
# 1      0.707509  0.912663  0.602531 -0.255562  0.714663 -0.781794  0.665224
# 2     -1.413295  0.011556 -1.659531 -0.255562 -0.677799 -0.781794 -2.036034
# 3      0.707509  2.437614  0.602531 -0.255562 -0.677799 -0.781794  0.665224
# 4      0.707509 -1.998605  0.602531 -0.255562 -0.677799 -0.781794 -2.036034
# ...         ...       ...       ...       ...       ...       ...       ...
# 12309  0.707509 -1.444078  0.602531 -0.255562  0.714663  0.519329  0.665224
# 12310 -1.413295  2.298982  0.602531 -0.255562  0.714663 -0.781794 -0.685405
# 12311  0.707509  1.328559  0.602531 -0.255562 -0.677799 -0.781794  0.665224
# 12312 -1.413295  0.774032  0.602531 -0.255562  0.714663  0.519329 -0.685405
# 12313  0.707509 -0.820235 -1.659531 -0.255562  0.714663  0.519329  0.665224
#
#          Q02901    Q03002      N001  ...      P023      P027      P035  \
# 0     -0.457339  0.353925  0.570681  ...  0.756081 -0.477009 -0.101505
# 1     -0.457339  0.353925  0.570681  ...  0.756081 -0.477009 -0.101505
# 2     -0.457339  0.353925  0.570681  ... -0.907259 -0.477009 -0.783037
# 3      2.346579  0.353925  0.570681  ...  0.756081 -0.477009 -0.783037
# 4      0.944620 -4.008673 -0.850136  ...  0.756081 -0.477009  0.920794
# ...         ...       ...       ...  ...       ...       ...       ...
# 12309 -0.457339 -1.827374 -0.850136  ...  0.756081 -0.477009  0.920794
# 12310 -0.457339  0.353925  0.570681  ...  0.756081 -0.477009  2.283858
# 12311  0.944620  0.353925  1.991498  ... -1.572595 -0.477009  0.580028
# 12312 -0.457339  0.353925 -0.850136  ...  0.756081 -0.477009  0.239261
# 12313  2.346579  0.353925 -0.850136  ...  0.756081 -0.477009  0.920794
#
#          P05401      P052      P053      P050      P058    VDF004    Q03001
# 0      2.090590 -1.495440 -0.584812  0.212058  2.499266  0.132223 -0.999959
# 1     -0.965339 -1.495440  0.115291  0.212058  3.291247 -0.574765 -0.999959
# 2      0.562626  0.703282  0.231975  0.212058 -0.668656  0.839211 -0.999959
# 3      2.090590  0.703282 -1.751650  0.212058  0.915305  0.132223 -0.999959
# 4     -0.201357 -0.396079  0.465342  0.212058  0.915305  0.132223 -0.999959
# ...         ...       ...       ...       ...       ...       ...       ...
# 12309  0.562626 -1.495440 -0.351444  0.212058 -0.668656 -1.281753  0.999959
# 12310  0.562626 -1.495440  0.582026  0.212058  2.499266 -0.574765  0.999959
# 12311  0.562626 -1.495440 -0.351444  0.212058 -0.668656 -0.574765  0.999959
# 12312 -0.965339 -0.396079  0.465342  0.212058 -0.668656  0.132223  0.999959
# 12313 -0.965339  0.703282  0.815394  0.212058 -0.668656  0.132223  0.999959
#
# [12314 rows x 27 columns]

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_std)
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
plt.figure(figsize=(8, 6))
plt.scatter(pca_df['PC1'], pca_df['PC2'], c=df['Q03001'].map({1: '#ba0909', 2: '#3452bf'}))
plt.title('Vizualização da Base')
plt.grid(True)
plt.show()
# Plot the data points in 2D

# %%
plt.figure(figsize=(8, 6))
plt.scatter(pca_df['PC1'], pca_df['PC2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('2D Plot of N-dimensional DataFrame')
plt.grid(True)
plt.show()
